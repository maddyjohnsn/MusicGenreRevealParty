# %%
import tarfile
import os

# %%
tarballs = ["spectrograms/raw_30s_melspecs-10.tar",
            "spectrograms/raw_30s_melspecs-11.tar", 
            "spectrograms/raw_30s_melspecs-12.tar",
            "spectrograms/raw_30s_melspecs-13.tar",
            "spectrograms/raw_30s_melspecs-14.tar",]
for tb in tarballs:
    extract_to ='C:/Users/olive/OneDrive/Desktop/DS/ANN_DIS/spectrograms/'
    with tarfile.open(tb, 'r') as tar:
        tar.extractall(path=extract_to)
        print(tb, ' extracted')
    os.remove(tb)
    print(tb, ' removed')
# Out:
# spectrograms/raw_30s_melspecs-10.tar  extracted
# spectrograms/raw_30s_melspecs-10.tar  removed
# spectrograms/raw_30s_melspecs-11.tar  extracted
# spectrograms/raw_30s_melspecs-11.tar  removed
# spectrograms/raw_30s_melspecs-12.tar  extracted
# spectrograms/raw_30s_melspecs-12.tar  removed
# spectrograms/raw_30s_melspecs-13.tar  extracted
# spectrograms/raw_30s_melspecs-13.tar  removed
# spectrograms/raw_30s_melspecs-14.tar  extracted
# spectrograms/raw_30s_melspecs-14.tar  removed
